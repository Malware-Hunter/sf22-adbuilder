# %%
import glob

time = []
cpu = []
mem = []

for file in glob.glob('*.txt'):
    print("\n*** abrindo arquivo:", file)
    with open(file, 'r') as f:
        for line in f:
            try:
                split = str(line).split(' ') # split[5] - tempo de execução (segundos)
                split_cpu = str(split[9]).split('%') # split_cpu[0] - % CPU utilizado
                split_mem = split[12] # split_mem - % memória utilizada
                time.append(split[5])
                cpu.append(split_cpu[0])
                mem.append(split_mem)
            except:
                print('Erro ao processar alguns valores do arquivo:', file)
# Out:
# *** abrindo arquivo: stats-000040290A90F689FB71A84A1D85064867E6A4924E5B034331BE716578D108A2.txt
#
# *** abrindo arquivo: stats-0000527D37451F842D5BA27F59C0646E9BE9B5F976421075BCE7630FAD1A58C1.txt
#
# *** abrindo arquivo: stats-0000764713B286CFE7E8E76C7038C92312977712D9C5A86D504BE54F3C1D025A.txt
#
# *** abrindo arquivo: stats-0000A7B09E2B695D069BC7BA4B9BD797F24EB532E0AD88666307913DDE8EDC2B.txt
#
# *** abrindo arquivo: stats-0001048C77B5FD01FD2C0C36155BB73C73533F4D3F06521AF7332BCD9BE4E319.txt
#
# *** abrindo arquivo: stats-0001DEC59F938FAB221FA876B198387B346DB3A6799B5B9917358C8C4E0EF7CF.txt
#
# *** abrindo arquivo: stats-0002F45E396B4D948ED0E9D2F818EC9F1B10F592347D43825CA2FF6A271A6867.txt
#
# *** abrindo arquivo: stats-0003D47ADE8F130801E263D4D26D487E66731B25D89D8AAECD5816AD830378EA.txt
#
# *** abrindo arquivo: stats-0004DA539598DBEE69156E64B3C82E294C819FA4C9432246C4C9E392670DEC52.txt
#
# *** abrindo arquivo: stats-00050EE1EFEE0602426671153AD0487A46C235D5FFB397427C96C832A6DB38A1.txt
#
# *** abrindo arquivo: stats-0006A22A1D0CB4175A3539B0D3BA453CAC8AD32C3133D33591800FA84324E10D.txt
#
# *** abrindo arquivo: stats-0006C02B163072546759FA6700701C1735CBF243EAE86C51481DC8C4A2E071FD.txt
#
# *** abrindo arquivo: stats-0006E3E18C1666579A2469BB8BDDFA3A632612F2E943DE6E1796F49421B5AB08.txt
#
# *** abrindo arquivo: stats-0007631191B108668F1FB8F139D95C059694A20D95B2145400B30B3741EF0E49.txt
#
# *** abrindo arquivo: stats-00077F1A34CC84DADEB5E04964A6D0FC83BA6D64EF1FD79FF92CE238936F0C89.txt
#
# *** abrindo arquivo: stats-00088E191503BBFBD5C56A789A71E8C718E42EA422EC73C760EE2DE489E02B2E.txt
#
# *** abrindo arquivo: stats-0008A46987C4BBECC020664892113112B0A5D47A09CC537B5A32FBE405A0CE57.txt
#
# *** abrindo arquivo: stats-0008B849C70477FAF464E80DF6C7EA91569F78BD2F13AF79924F8B5341A44EDD.txt
#
# *** abrindo arquivo: stats-00093B4EDF37672F1192D4FADDC05CF40D43234B06118D25AAA1B2AF0D08B7B6.txt
#
# *** abrindo arquivo: stats-000952BC2EEE0C342B6A6EDD8FD4F82B15E51CB3D2A4A04BF53677243B542D78.txt
#
# *** abrindo arquivo: stats-00099FCA1886B99919847167931CDE313DEE8372001026AA17A730806A64F261.txt
#
# *** abrindo arquivo: stats-0009AE23FBDA97926F1BA3845B00471378B5F00704F2FD27319061FBB752F279.txt
#
# *** abrindo arquivo: stats-000A0397564123673D14131BE4B7AA8BC2D10EFC57ECCB5DA83915B7692C6EB5.txt
#
# *** abrindo arquivo: stats-000A8593DC596F5015263D8C54A527D36709344D3626CE03BB10B8C2E76B2EF4.txt
#
# *** abrindo arquivo: stats-000C2F0C7A69CF15D31C27116C53B6C2141C0C45BCA9BDDCC937803CB525A0A7.txt
#
# *** abrindo arquivo: stats-000C6BB100B3A78D2C132DA626558D259E7ECE95E728517C94CFBE40DEC7C551.txt
#
# *** abrindo arquivo: stats-000E0948176BDEC2B6E19D0F03E23F37910676A9B7E7709954614BAC79269C36.txt
#
# *** abrindo arquivo: stats-000E5E567E15597B2FDF803F59313F9F52C6F70C2346A1EA1650F090BB4CC6BF.txt
#
# *** abrindo arquivo: stats-000E7149AB7550EF605C2B22CB1BEAFFBEE9219699661D89158D490A3FFA393A.txt
#
# *** abrindo arquivo: stats-00111AD8824985A5156449965A56D208D23CC0C1E7A6E2D52F925E5AA4F1039C.txt
#
# *** abrindo arquivo: stats-0012DA08D94DE6FB62ECB01C3D25DD31288D08FE40C471AFDE1EC7069B632377.txt
#
# *** abrindo arquivo: stats-001436B85C34F9E5FCABB437C3055B3693A108C350C061AD48EBEA10FE04F416.txt
#
# *** abrindo arquivo: stats-00161B1614CB7B10F57BE818640A2BBBC92FF596FE977AAB93546E92BBDCA420.txt
#
# *** abrindo arquivo: stats-001673502768F25B448CA513C0EB56954694A31F84543F70C6FEC99A5D5F6BFC.txt
#
# *** abrindo arquivo: stats-0016B3D270A9C97E2A5DF8C7F063DABECB09BBF93BE090F9DE2BE65E91E178BE.txt
#
# *** abrindo arquivo: stats-0016D40668E1669A70EACDE221B3EEABB47565060B91FF8934D9D42E777E7CA8.txt
#
# *** abrindo arquivo: stats-0016F5ED0FE16426C1A2B2B9BD5D2F42E893D9C0004E6E542EB2093D5A7ED705.txt
#
# *** abrindo arquivo: stats-00173A6F404EBCB07E4CD4A877F622C4FCE2F0320DFB4811CF1D9DD5D99F95E0.txt
#
# *** abrindo arquivo: stats-001884E3E90DE260D1274495E574D4ECF5403D7030F9AE4D352A2DC24C06340C.txt
#
# *** abrindo arquivo: stats-0018EA6E7CEA36E61B0383B451938EED22BCD473BE4FA9860692985944B720E5.txt
#
# *** abrindo arquivo: stats-001912442A3E0FBF3AE332BC1FA9C4CF7B330BEDC05825D30894965FF2205A48.txt
#
# *** abrindo arquivo: stats-001913E6883C300105C7CE4C4372621F44D57450F8B4F85E598338A035462176.txt
#
# *** abrindo arquivo: stats-0019519DA8E5A665EA3EBF4C3D7CDCCBEA74CC14DE87A00AC18ACD02A68D1841.txt
#
# *** abrindo arquivo: stats-001A7738780E0A5F2FAE69D1C0B9015DA0A72DFD895E2E7C2526510475909ECB.txt
#
# *** abrindo arquivo: stats-001C88754DEE6CCCA002F4909109DF90D6F78791B5D25400699FAD5BABED5050.txt
#
# *** abrindo arquivo: stats-001CA3D260A15A01121C33F9EE7576D33DE20C4D42425D5CC18D1337AFF3CB79.txt
#
# *** abrindo arquivo: stats-001D38F5BBD3DB64E62A829C90F447033405BF51DA21E0A474A239099D7B6E21.txt
#
# *** abrindo arquivo: stats-001E0947B0297FB42094763B396D4F9EB8DFE539A1B095A77857A8D6D6A3852B.txt
#
# *** abrindo arquivo: stats-001E1D5CC4B94A7F3177E4C607C2015BEBB67C19E707165667EDB4FA6F712ED7.txt
#
# *** abrindo arquivo: stats-001EDF856F5E07D183BCEEEAD3E7147B6A3AE6A24749B2B8144FF08F9727D109.txt
#
# *** abrindo arquivo: stats-001F0C479D193364C3C9258014186BFDFE8E1837300D0F52A9165EAEF12C5846.txt
#
# *** abrindo arquivo: stats-00210A60CA90E42DE0E361EBE7CB3E95ED99EC2B72B0EED931FF704BF425D6C0.txt
#
# *** abrindo arquivo: stats-0022479EA61D9AA4B0CB7E31441C5466C2A784349A27DD9C60693CDB865496CB.txt
#
# *** abrindo arquivo: stats-0024F5BA000879C1CC9284B93B5E1FF31A134413353648B163A35A0FD251E2DC.txt
#
# *** abrindo arquivo: stats-00257F4F8E3F5B61ABD5C985F0DF6FAE48882FFD977A6EA79341B9E61191B246.txt
#
# *** abrindo arquivo: stats-0025AD53A2C025E8778B77D2D53AD0E3FD47C7A8BCC3282FDEB27ED5928845B4.txt
#
# *** abrindo arquivo: stats-0025F94ED7DEFB1F063B30463612F6795C0C5AA0786D51F49722E17962D2BAE2.txt
#
# *** abrindo arquivo: stats-0026989DF565BDCB261DFF58EB20EB5E56DEE2927E63A7A485468A271819849C.txt
#
# *** abrindo arquivo: stats-0026ADEC3CC9B96DD89D1FB3F5C48598BBC32225DF62D8027D817291116D5864.txt
#
# *** abrindo arquivo: stats-002736EC6465D58043239C8EF3B0D17E86BB34F74E4A418A23CAD331DF02522C.txt
#
# *** abrindo arquivo: stats-002755634A63F34E4AABEB56DDBB5DD113BB4302DF34031337FA90C2C3841815.txt
#
# *** abrindo arquivo: stats-002841B219C80C4CCE0A33C5A62899C9C064264E2DFAC01CCBF117258B59731D.txt
#
# *** abrindo arquivo: stats-002878CED9796BE7A84A7E68E7151CFCE5E77920C6A9DFF0F7AFAED103984535.txt
# Erro ao processar alguns valores do arquivo: stats-002878CED9796BE7A84A7E68E7151CFCE5E77920C6A9DFF0F7AFAED103984535.txt
#
# *** abrindo arquivo: stats-00287BF74288C67D4EBF1F6D352C4D80548CB4F7D6A12459EC4DE9D4555106F4.txt
#
# *** abrindo arquivo: stats-0029333C3985B712C6D656B34AB0F5B9F9AC1F439210ABB95532C38EE6373C28.txt
#
# *** abrindo arquivo: stats-002A21420531A272BF792BD55D9A0AB0F4D2995EA13FEC9D26A86EF3BBF5DF22.txt
#
# *** abrindo arquivo: stats-002ADB28AF57BDEDDFAAF8E70FB7629A72C0CC538E7582060ACFCEF6CDE29EA2.txt
#
# *** abrindo arquivo: stats-002B22B2DE025F0F62CE9A04F0C673FEC5756A4A09CB7FF36BB771A6C9AF4FF2.txt
#
# *** abrindo arquivo: stats-002BD922800D3BAA8E8EFA770DF86A8D46E1925AA84EADDBE8C7AF31A45937F8.txt
#
# *** abrindo arquivo: stats-002C146A848C5787A65D0B4E8221C1A9A7043DA494FB4E9FBA3F4CEF261DA0DD.txt
#
# *** abrindo arquivo: stats-002C659936C53F065AAE248608B73F5E90C865DB0F55DF4C4BFC221604BE8EA8.txt
#
# *** abrindo arquivo: stats-002C90FE32F4B21C5FE2583D1CB9322F075C718A9FE0462FD32E1C5B5868BAAE.txt
#
# *** abrindo arquivo: stats-002D2EBAC804745C10198869AC73044E78A83659969AA37C93745ECF9E499221.txt
#
# *** abrindo arquivo: stats-002D5FF6933394B0802858E47E9F011055DB2D8783CE7CE9B54C5EF4177A367A.txt
#
# *** abrindo arquivo: stats-002E5BF3AC17260E8E095212F96273AB5691C3B67856D94328A84933B3E5081C.txt
#
# *** abrindo arquivo: stats-002F1837C6F633E2C991627614CDBFE06F98F39A8A6B13305176431ADFDC7707.txt
#
# *** abrindo arquivo: stats-002FCAA7D81F4950C4EC199B6707E5E1264F4A861F331715F22ED57BD6611339.txt
#
# *** abrindo arquivo: stats-002FD9FD1A2BE4E8CEBB3A4AAC18D08FD8ED0A9489C2F74E452B444B4FEBCFED.txt
#
# *** abrindo arquivo: stats-0030C38FA4FE0EF60F05E0699FA8EC2DD10E30C494106378B7A14C9AB1222AAE.txt
#
# *** abrindo arquivo: stats-00314A59DF26AF17B0E5E4AA366D4CA6AF97998A9CD85F939FFE4D315D8956F1.txt
#
# *** abrindo arquivo: stats-00354041EC44065ED5F346FE6396649A8C76DA7E6B99F42D4FC12D4F2B4A86C6.txt
#
# *** abrindo arquivo: stats-003560E31501F1A19D1EA8B109EB5C5A6C82BC9D2D7CEC5524BAD3A1DC473882.txt
#
# *** abrindo arquivo: stats-0035B4FE1F5E5F2133E1EA0E01E34EF0B91855EBD03EF7211845A0B6FE76C0F6.txt
#
# *** abrindo arquivo: stats-00366DB4C96D406AE4BC78CDB0261F748F12BFA63B5EC9E056719B344C0F37F8.txt
#
# *** abrindo arquivo: stats-00374438AE75D905DA2403CEEFD1D9C31E95B3DEAFEF53CAB5CCA3657D45DA72.txt
#
# *** abrindo arquivo: stats-0039247C53D4430BF0822BA269086C99EFCCDE6B27461F03900FA0D8EE543817.txt
#
# *** abrindo arquivo: stats-003BB779735917E1B029EE1ECEFA0EFC5AECBC82004A38E06468544955317A0C.txt
#
# *** abrindo arquivo: stats-003CB8A203421FD65E65917567DF2933710A6A0A94B2B877B16296646CF0998D.txt
#
# *** abrindo arquivo: stats-003D514B089D8AA5B207E046C184F8BFDC4DFB4F58B85B7131EDC7C741622517.txt
#
# *** abrindo arquivo: stats-003DA5C71E758672CAA784C63215ABF6838488760D2DABD6644AEBA602F056BA.txt
#
# *** abrindo arquivo: stats-003F5A556527134C76B39D3DCE6E6B6255201BD27EE19FDCFBBA6E2280B507D3.txt
#
# *** abrindo arquivo: stats-003FF7FB7C2FA27F65945C627B0C77246AFCE387CCDEB45A3D5F9F3AD2DDED51.txt
#
# *** abrindo arquivo: stats-00404840DB4C5597B13A9297614832EB2D6F6B8D6EA3E4E6FC49D21267615FBF.txt
#
# *** abrindo arquivo: stats-00453CA8895FD43A2509E3B731CEEF37A337FE61A36DB3ECE0F2952E3EDEEBC8.txt
#
# *** abrindo arquivo: stats-0049B80C02AAA7DC86305088A4571B5DFA68F2FCB1205768E53F8CCFEBA0DC45.txt
#
# *** abrindo arquivo: stats-004A4B85C4FE43BDCCE4F71D6D247C447D1132FDF975FA904DDE84A08404296A.txt
#
# *** abrindo arquivo: stats-004B3862F816F35464FE8F1E45D56628B299D32B25F47ED4D308251F4B250D19.txt
#
# *** abrindo arquivo: stats-004C9C99C0AA7D47F929063939DA4E95BB9786DF239864249CFB695029DDB0CF.txt
#
# *** abrindo arquivo: stats-004D92FBF197F97658F817F0D7CA7219729DB23B8211A18F3C5A2BC0120E4C0D.txt
#
# *** abrindo arquivo: stats-004E604754363D5DAE6A5B15FEC40C1CE81BB516E63CF75D438A905AD76651AB.txt

# %%
import pandas as pd

df = pd.DataFrame({'Tempo de Execução (s)': time, 'CPU (%)': cpu, 'Memória RAM': mem})
for col in df:
    df[col] = df[col].astype(float)
df.head()
# Out:
#    Tempo de Execução (s)  CPU (%)  Memória RAM
# 0                   1.64     97.0     127956.0
# 1                   2.73     89.0     152956.0
# 2                   0.80    278.0     142844.0
# 3                   8.01    112.0     297652.0
# 4                   3.68    132.0     204876.0

# %%
df.describe()
# Out:
#        Tempo de Execução (s)    CPU (%)    Memória RAM
# count             100.000000  100.00000     100.000000
# mean                4.241800  142.59000  179330.000000
# std                 3.803668   36.49411   57642.399284
# min                 0.740000   89.00000  124560.000000
# 25%                 1.765000  113.00000  132712.000000
# 50%                 2.710000  135.50000  153634.000000
# 75%                 5.530000  163.00000  210844.000000
# max                23.000000  278.00000  369204.000000
