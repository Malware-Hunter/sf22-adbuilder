# %%
import pandas as pd

df = pd.read_csv("MotoDroid_dataset.csv")
df.shape
# Out:
# (99, 4504)

# %%
df.head()
# Out:
#                                               SHA256             NOME  \
# 0  000040290a90f689fb71a84a1d85064867e6a4924e5b03...     종로자세굿재활의학과의원
# 1  0000527d37451f842d5ba27f59c0646e9be9b5f9764210...  NCLEX Questions
# 2  0000764713b286cfe7e8e76c7038c92312977712d9c5a8...        Installer
# 3  0000a7b09e2b695d069bc7ba4b9bd797f24eb532e0ad88...   Goboko Booking
# 4  0001048c77b5fd01fd2c0c36155bb73c73533f4d3f0652...          EasyRSS
#
#                        PACOTE  API_MIN  API  Permission :: INTERNET  \
# 0             com.jase.kr.web        9   28                       1
# 1  com.applern.nclexquestions       22   30                       1
# 2                  tp5x.WGt12        4    4                       1
# 3           com.goboko.Goboko       19   28                       1
# 4        org.freshrss.easyrss        7   29                       1
#
#    Permission :: READ_PHONE_STATE  \
# 0                               1
# 1                               0
# ...

# %%
for col in df:
    print(col)
# Out:
# SHA256
# NOME
# PACOTE
# API_MIN
# API
# Permission :: INTERNET
# Permission :: READ_PHONE_STATE
# API Call :: Landroid/webkit/WebChromeClient.init()
# API Call :: Landroid/widget/RelativeLayout.removeView()
# API Call :: Landroid/webkit/WebView.destroy()
# API Call :: Landroid/webkit/WebChromeClient.onCloseWindow()
# API Call :: Landroid/webkit/WebView.init()
# API Call :: Landroid/widget/RelativeLayout.addView()
# API Call :: Landroid/webkit/WebView$WebViewTransport.setWebView()
# API Call :: Landroid/webkit/WebView.setWebChromeClient()
# API Call :: Landroid/webkit/WebView.setWebViewClient()
# API Call :: Landroid/os/Message.sendToTarget()
# API Call :: Landroid/webkit/WebView.getContext()
# API Call :: Landroid/webkit/WebViewClient.init()
# API Call :: Landroid/webkit/WebViewClient.onPageFinished()
# API Call :: Landroid/widget/Toast.show()
# API Call :: Landroid/widget/Toast.makeText()
# API Call :: Landroid/net/http/SslError.getPrimaryError()
# ...
