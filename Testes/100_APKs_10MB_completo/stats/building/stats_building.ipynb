# %%
import glob

time_geration = []
time_convert = []
time_concat = []

for file in glob.glob('*.log'):
    print("\n*** abrindo arquivo:", file)
    if "Concat" in file:
        with open(file, 'r') as f:
            for line in f:
                #print(line)
                if "INT" in line:
                    try:
                        split = str(line).split('  ') # split[1] - tempo de execução (segundos)
                        time_convert.append(float(split[1]))
                    except:
                        ''
                if "CSV" in line:
                    try:
                        split = str(line).split('  ') # split[1] - tempo de execução (segundos)
                        split_aux = str(split[1]).split(' ')
                        time_concat.append(float(split_aux[0]))
                    except:
                        ''
                
    elif "Geration" in file:
        with open(file, 'r') as f:
            for line in f:
                if "Tempo" in line:
                    try:
                        split = str(line).split(' ') # split[7] - tempo de execução (segundos)
                        time_geration.append(float(split[7]))
                    except:
                        ''
# Out:
# *** abrindo arquivo: Concat-20220728081344.log
#
# *** abrindo arquivo: Geration-20220728081344.log

# %%
import pandas as pd

df = pd.DataFrame({'Tempo de Geração (s)': time_geration, 'Tempo de Conversão para INT (s)': time_convert, 'Tempo de Concatenação (s)': time_concat})
df['Tempo de building (s)'] = df['Tempo de Geração (s)'] + df['Tempo de Conversão para INT (s)'] + df['Tempo de Concatenação (s)']
df.head()
# Out:
#    Tempo de Geração (s)  Tempo de Conversão para INT (s)  \
# 0              1.019777                         0.645701
# 1              0.979067                         0.503385
# 2              1.817453                         0.675150
# 3              1.006953                         0.792680
# 4              1.454280                         0.842304
#
#    Tempo de Concatenação (s)  Tempo de building (s)
# 0                   0.806781               2.472258
# 1                   0.622215               2.104666
# 2                   0.788767               3.281370
# 3                   1.141456               2.941090
# 4                   1.050666               3.347250

# %%
df.describe()
# Out:
#        Tempo de Geração (s)  Tempo de Conversão para INT (s)  \
# count            100.000000                       100.000000
# mean               1.385213                         1.283590
# std                1.006620                         0.501862
# min                0.022428                         0.470453
# 25%                0.814288                         0.891602
# 50%                1.269921                         1.126521
# 75%                1.783847                         1.603652
# max                4.781762                         2.705294
#
#        Tempo de Concatenação (s)  Tempo de building (s)
# count                 100.000000             100.000000
# mean                    1.699180               4.367982
# std                     0.618893               1.508115
# min                     0.622215               1.795286
# 25%                     1.220947               3.329419
# 50%                     1.506357               4.176063
# 75%                     2.149015               5.376006
# max                     3.322992               8.723516
