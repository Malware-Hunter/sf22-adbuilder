# %%
import glob

time_geration = []
time_convert = []
time_concat = []

for file in glob.glob('*.log'):
    print("\n*** abrindo arquivo:", file)
    if "Concat" in file:
        with open(file, 'r') as f:
            for line in f:
                #print(line)
                if "INT" in line:
                    try:
                        split = str(line).split('  ') # split[1] - tempo de execução (segundos)
                        time_convert.append(float(split[1]))
                    except:
                        ''
                if "CSV" in line:
                    try:
                        split = str(line).split('  ') # split[1] - tempo de execução (segundos)
                        split_aux = str(split[1]).split(' ')
                        time_concat.append(float(split_aux[0]))
                    except:
                        ''
                
    elif "Geration" in file:
        with open(file, 'r') as f:
            for line in f:
                if "Tempo" in line:
                    try:
                        split = str(line).split(' ') # split[7] - tempo de execução (segundos)
                        time_geration.append(float(split[7]))
                    except:
                        ''
# Out:
# *** abrindo arquivo: Concat-20220726113246.log
#
# *** abrindo arquivo: Geration-20220726113246.log

# %%
import pandas as pd

df = pd.DataFrame({'Tempo de Geração (s)': time_geration, 'Tempo de Conversão para INT (s)': time_convert, 'Tempo de Concatenação (s)': time_concat})
df['Tempo de building (s)'] = df['Tempo de Geração (s)'] + df['Tempo de Conversão para INT (s)'] + df['Tempo de Concatenação (s)']
df.head()
# Out:
#    Tempo de Geração (s)  Tempo de Conversão para INT (s)  \
# 0              1.332714                         0.681252
# 1              2.351797                         0.720585
# 2              1.894411                         1.096880
# 3              0.028529                         0.725672
# 4              2.874716                         0.975605
#
#    Tempo de Concatenação (s)  Tempo de building (s)
# 0                   0.836743               2.850709
# 1                   0.928241               4.000623
# 2                   1.413818               4.405108
# 3                   1.064972               1.819174
# 4                   1.328334               5.178655

# %%
df.describe()
# Out:
#        Tempo de Geração (s)  Tempo de Conversão para INT (s)  \
# count             99.000000                        99.000000
# mean               1.332499                         3.146009
# std                1.664967                         1.799842
# min                0.007139                         0.681252
# 25%                0.010850                         1.766170
# 50%                0.028529                         2.603324
# 75%                2.661235                         4.382654
# max                6.353369                         8.462050
#
#        Tempo de Concatenação (s)  Tempo de building (s)
# count                  99.000000              99.000000
# mean                    4.066799               8.545307
# std                     2.219575               3.859614
# min                     0.836743               1.819174
# 25%                     2.287358               5.901982
# 50%                     3.382493               7.672366
# 75%                     5.586661              10.671671
# max                     9.880821              18.353368
