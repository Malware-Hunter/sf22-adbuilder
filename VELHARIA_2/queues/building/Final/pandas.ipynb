# %%
import pandas as pd

df = pd.read_csv("MotoDroid_dataset.csv")
df.head()
# Out:
#                                               SHA256  \
# 0  028f26390a79c1722f56e730a4aab5019ffca4a39b5782...
# 1  2570e36a4b90b60d2d35d367ec29f33e77b0f851d5b332...
# 2  25706aa52cd3fa51753ba2957cceda34d22aa084c00a14...
# 3  25d6f36260bf081c928ff7ca9b0e20dd2e271d91ad1afc...
# 4  25d7bb0e1b098762f3f5969b1db84aed22e6003c2ae1f2...
#
#                             NOME  \
# 0                     HifazatDua
# 1  Prank Call From Ariana Grande
# 2                        BOYZONE
# 3               AadharCardOnline
# 4                           宜搜小说
#
#                                               PACOTE  API_MIN  API  \
# 0                             com.appsvolt.brkthfzat       10   26
# 1                         com.Ariana.Grande.call.you       14   30
# 2             com.appybuilder.ritazuriati82.Boyz_App       14   26
# 3  com.appybuilder.Shushilakukreja10.AadharCardOn...       14   22
# 4                                cn.yisouxiaoshuo.xs       16   26
#
# ...

# %%
df_aux = pd.DataFrame()
df_aux['SHA256'] = df['SHA256']
df_aux['CLASS'] = df['CLASS']
df_aux.head(10)
# Out:
#                                               SHA256  CLASS
# 0  028f26390a79c1722f56e730a4aab5019ffca4a39b5782...      0
# 1  2570e36a4b90b60d2d35d367ec29f33e77b0f851d5b332...      0
# 2  25706aa52cd3fa51753ba2957cceda34d22aa084c00a14...      1
# 3  25d6f36260bf081c928ff7ca9b0e20dd2e271d91ad1afc...      1
# 4  25d7bb0e1b098762f3f5969b1db84aed22e6003c2ae1f2...      2
# 5  25d8c05a54f6de5f466bf2b4c90d454b8dffd04aba1197...      3
# 6  25d9f53984bf1b8f5b83bc528b17c60df6e2a261afb038...      7
# 7  25d6e1d863c7fbd24ae105ded0aefd139b80ee578ec925...      1
# 8  25da0bce152eccd0432f2127d1a4fd5269899670afee3c...      0
# 9  25d6d8d5dfab945ee0df899e3f06f35bbc19318cdcd267...      1
